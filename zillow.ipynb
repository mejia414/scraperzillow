# %%
# !pip install -r requirements.txt

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime
import time

# %%
class Zillow():
    def __init__(self):
        
        
        self.headers= {
                        'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
                        'accept-encoding':'gzip, deflate, sdch, br',
                        'accept-language':'en-GB,en;q=0.8,en-US;q=0.6,ml;q=0.4',
                        'cache-control':'max-age=0',
                        'upgrade-insecure-requests':'1',
                        'user-agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'
            }
        self.data=[]

    def create_url(self, zipcode, city, county, method_url):
        
        self.zipcode = zipcode
        self.city = city
        self.county = county

        self.method_url= method_url

        if self.method_url==0:
            url = "https://www.zillow.com/homes/for_sale/{0}/0_singlestory/days_sort".format(self.zipcode)
        if self.method_url==1:
            url = "https://www.zillow.com/homes/for_sale/{0}/0_singlestory/pricea_sort".format(self.zipcode)
        
        self.url = url

        return self.url

    def query_zillow_requests(self):
        res=requests.get(url=self.url, headers=self.headers)

        self.status_code = res.status_code
        self.html = res.text

        return (self.url, self.status_code)
    
    def extract_zillow_info(self):
        if self.status_code==200:
          soup = BeautifulSoup(self.html, 'html.parser')
          contents = soup.find_all('a',class_='list-card-link list-card-link-top-margin list-card-img')
          
          for content in contents:
              self.url_zillow = str(content.attrs.get('href'))

              dicc_info = {'date': datetime.datetime.now() ,'zipcode:':str(self.zipcode), 'city:' : str(self.city), 'county' : str(self.county),  'url': self.url_zillow }
              dicc_info.update(self.extract_zillow_info_detail())
              print(dicc_info)
              self.data.append(dicc_info)

        return self.data

    def extract_zillow_info_detail(self):
        
        req = requests.get(url=self.url_zillow, headers=self.headers)
        soup = BeautifulSoup(req.text, "lxml")

        dicc_zillow = {}

        i = 0
        dicc = {}

        for sub_soup in soup.find_all('div', class_='ds-home-details-chip'):
            dicc[i] = sub_soup.find(
                class_='Text-c11n-8-18-0__aiai24-0 StyledHeading-c11n-8-18-0__ktujwe-0 gcaUyc sc-pscky cYZqfq').get_text()
            i = i+1

        dicc_zillow['price:'] = str(dicc[0])

        i = 0
        dicc = {}

        for sub_soup in soup.find_all('h3', class_='ds-bed-bath-living-area-container'):
            for sub_sub_soup in soup.find_all('span', class_='ds-bed-bath-living-area', limit=3):
                dicc[i] = sub_sub_soup.get_text()
                i = i+1

        for j in range(i):
            dicc_zillow[str(dicc[j]).split(' ')[1]] = str(dicc[j]).split(' ')[0]

        dicc_tag = {}
        dicc_value = {}

        for sub_soup in soup.find_all('ul', class_='ds-home-fact-list'):
            i = 0
            for sub_sub_soup in soup.find_all('span', class_='Text-c11n-8-18-0__aiai24-0 sc-pTWqp kdrGgn', limit=10):
                dicc_tag[i] = sub_sub_soup.get_text()
                i = i+1
            i = 0
            for sub_sub_soup in soup.find_all('span', class_='Text-c11n-8-18-0__aiai24-0 foiYRz', limit=10):
                dicc_value[i] = sub_sub_soup.get_text()
                i = i+1
        for j in range(i):
            try:
                dicc_zillow[str(dicc_tag[j])] = str(dicc_value[j])
            except:
                continue

        return dicc_zillow

    def Create_file_zillow_excel(self):
        df=pd.DataFrame(self.data)
        df = df.drop_duplicates(subset=['url'])
        df.to_excel('info.xlsx', sheet_name='master', index=False)
        
        return df
        
    def sleep_scrapper_zillow(self):
        if self.status_code==200:
            print(self.status_code)
            time.sleep(10)
        else:
            print(self.status_code)
            time.sleep(200)
        return self.status_code

# %%
io='data.xlsx'

df = pd.read_excel(io=io, sheet_name='master')
mizillow = Zillow()

for i in range(df.shape[0]):
    if df.loc[i, 'state_of_query'] == 1:
        
        zipcode = df.loc[i, 'zipcode']
        city = df.loc[i, 'city']
        county = df.loc[i, 'county']

        try:
            mizillow.create_url(zipcode=zipcode,city=city,county=county, method_url=0)
            mizillow.query_zillow_requests()
            mizillow.extract_zillow_info()
            mizillow.sleep_scrapper_zillow()

            mizillow.create_url(zipcode=zipcode,city=city,county=county, method_url=1)
            mizillow.query_zillow_requests()
            mizillow.extract_zillow_info()
            mizillow.sleep_scrapper_zillow()
        except:
            continue

mizillow.Create_file_zillow_excel()

df.loc[i, 'last_date_of_query'] = datetime.datetime.now()

df.to_excel(io, sheet_name='master', index=False)
# Out:
# atetime(2020, 12, 26, 3, 18, 48, 461866), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/5055-Dixie-Hwy-106-Palm-Bay-FL-32905/2076991390_zpid/', 'price:': '$290,000', 'bd': '3', 'ba': '2', 'sqft': '1,480', 'Type:': 'Condo', 'Year built:': '1988', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': 'Garage - Attached, Covered', 'HOA:': '$460/mo', 'Price/sqft:': '$196'}
# {'date': datetime.datetime(2020, 12, 26, 3, 18, 49, 358830), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/784-Cranbrook-Ave-NE-Palm-Bay-FL-32905/43498788_zpid/', 'price:': '$169,999', 'bd': '5', 'ba': '3', 'sqft': '1,792', 'Type:': 'Single Family', 'Year built:': '1976', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': 'Garage, Garage - Attached', 'Lot:': '10,454 sqft', 'Price/sqft:': '$95'}
# {'date': datetime.datetime(2020, 12, 26, 3, 18, 50, 316417), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/2310-Coconut-Palm-Dr-NE-Palm-Bay-FL-32905/49906726_zpid/', 'price:': '$134,900', 'bd': '2', 'ba': '2', 'sqft': '1,032', 'Type:': 'Mobile / Manufactured', 'Year built:': '1986', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': 'Carport, Covered', 'HOA:': '$35/mo', 'Price/sqft:': '$131'}
# {'date': datetime.datetime(2020, 12, 26, 3, 18, 51, 263586), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/1448-Scepter-Ct-NE-Palm-Bay-FL-32905/43499599_zpid/', 'price:': '$309,900', 'bd': '3', 'ba': '3', 'sqft': '2,066', 'Type:': 'Single Family', 'Year built:': '1974', 'Heating:': 'Forced air, Electric', 'Cooling:': 'Central', 'Parking:': 'Garage, Garage - Attached, Covered', 'Lot:': '0.29 Acres', 'Price/sqft:': '$150'}
# {'date': datetime.datetime(2020, 12, 26, 3, 18, 52, 226234), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/3274-Dade-Cir-NE-Palm-Bay-FL-32905/43496383_zpid/', 'price:': '$170,000', 'bd': '3', 'ba': '2', 'sqft': '1,298', 'Type:': 'Single Family', 'Year built:': '1973', 'Heating:': 'Forced air, Electric', 'Cooling:': 'Central', 'Parking:': 'Carport, Covered', 'Lot:': '7,405 sqft', 'Price/sqft:': '$131'}
# {'date': datetime.datetime(2020, 12, 26, 3, 18, 53, 63836), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/2383-Coconut-Palm-Dr-NE-Palm-Bay-FL-32905/43492989_zpid/', 'price:': '$125,000', 'bd': '2', 'ba': '2', 'sqft': '1,027', 'Type:': 'Mobile / Manufactured', 'Year built:': '1992', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': 'Carport, Covered', 'Price/sqft:': '$122'}
# 200
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 5, 135254), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/2681-3rd-Ave-NE-Palm-Bay-FL-32905/43495645_zpid/', 'price:': '$38,320', 'bd': '2', 'ba': '2', 'sqft': '1,056', 'Type:': 'Single Family', 'Year built:': '1984', 'Heating:': 'None', 'Cooling:': 'None', 'Parking:': '0 spaces', 'Lot:': '9,147 sqft'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 5, 939118), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/2346-Port-Malabar-Blvd-NE-Palm-Bay-FL-32905/43496590_zpid/', 'price:': '$39,390', 'bd': '3', 'ba': '2', 'sqft': '1,272', 'Type:': 'Single Family', 'Year built:': '1963', 'Heating:': 'Other', 'Cooling:': 'Central', 'Parking:': 'Garage, Garage - Attached, Covered', 'Lot:': '7,405 sqft'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 6, 909807), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/1212-Cimarron-Cir-NE-Palm-Bay-FL-32905/43495436_zpid/', 'price:': 'Zestimate®:\xa0$299,313', 'bd': '4', 'ba': '--', 'sqft': '2,253', 'Type:': 'Single Family', 'Year built:': '1976', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': 'Garage, Garage - Attached', 'Lot:': '0.30 Acres'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 7, 770028), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/14-Port-Malabar-Blvd-NE-Palm-Bay-FL-32905/104098607_zpid/', 'price:': '$15,000', 'Square': '10,454', 'Type:': 'Vacant Land', 'Year built:': 'No Data', 'Heating:': 'No Data', 'Cooling:': 'No Data', 'Parking:': '0 spaces'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 8, 622033), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/1182-Jordan-Ct-NE-Palm-Bay-FL-32905/299495165_zpid/', 'price:': '$17,900', 'Acres': '0.25', 'Type:': 'Vacant Land', 'Year built:': 'No Data', 'Heating:': 'No Data', 'Cooling:': 'No Data', 'Parking:': '0 spaces'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 9, 436120), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/1941-Myrtle-Ct-NE-Palm-Bay-FL-32905/104086754_zpid/', 'price:': '$24,900', 'Square': '3,920', 'Type:': 'Vacant Land', 'Year built:': 'No Data', 'Heating:': 'No Data', 'Cooling:': 'No Data', 'Parking:': '0 spaces', 'HOA:': '$83/mo'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 10, 364456), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/1134-Glenham-Dr-NE-Palm-Bay-FL-32905/104077259_zpid/', 'price:': '$29,400', 'Acres': '0.32', 'Type:': 'Vacant Land', 'Year built:': 'No Data', 'Heating:': 'No Data', 'Cooling:': 'No Data', 'Parking:': '0 spaces'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 11, 200435), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/1111-Ver-Cir-NE-Palm-Bay-FL-32905/104114652_zpid/', 'price:': '$29,500', 'Acres': '0.25', 'Type:': 'Vacant Land', 'Year built:': 'No Data', 'Heating:': 'No Data', 'Cooling:': 'No Data', 'Parking:': '0 spaces'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 12, 92446), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/980-Cadillac-Dr-NE-Palm-Bay-FL-32905/104146409_zpid/', 'price:': '$40,000', 'Acres': '0.43', 'Type:': 'Vacant Land', 'Year built:': 'No Data', 'Heating:': 'No Data', 'Cooling:': 'No Data', 'Parking:': '0 spaces'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 12, 976096), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/2802-Morris-Ave-Palm-Bay-FL-32905/2078195849_zpid/', 'price:': '$48,000', 'Square': '8,712', 'Type:': 'Vacant Land', 'Year built:': 'No Data', 'Heating:': 'No Data', 'Cooling:': 'No Data', 'Parking:': '0 spaces'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 13, 828781), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/2967-Indian-River-Dr-NE-Palm-Bay-FL-32905/43496215_zpid/', 'price:': '$49,900', 'bd': '2', 'ba': '2', 'sqft': '672', 'Type:': 'Mobile / Manufactured', 'Year built:': '1968', 'Heating:': 'Heat pump, Electric', 'Cooling:': 'Central', 'Parking:': 'Carport, Covered', 'Price/sqft:': '$74'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 14, 708470), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/3131-Indian-River-Dr-NE-Palm-Bay-FL-32905/43496077_zpid/', 'price:': '$56,500', 'bd': '2', 'ba': '2', 'sqft': '672', 'Type:': 'Mobile / Manufactured', 'Year built:': '1973', 'Heating:': 'No Data', 'Cooling:': 'No Data', 'Parking:': 'Garage, Carport, Covered', 'HOA:': '$180/mo', 'Price/sqft:': '$84'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 15, 600106), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/2596-1st-Ave-NE-Palm-Bay-FL-32905/2081994576_zpid/', 'price:': '$59,900', 'Acres': '0.28', 'Type:': 'Vacant Land', 'Year built:': 'No Data', 'Heating:': 'No Data', 'Cooling:': 'No Data', 'Parking:': '0 spaces'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 16, 491636), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/000-Tree-Ridge-Ln-Palm-Bay-FL-32905/2091678325_zpid/', 'price:': '$60,000', 'Acres': '0.43', 'Type:': 'Vacant Land', 'Year built:': 'No Data', 'Heating:': 'No Data', 'Cooling:': 'No Data', 'Parking:': '0 spaces'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 17, 425870), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/1380-Turkey-Creek-Dr-NE-60-Palm-Bay-FL-32905/2081568423_zpid/', 'price:': '$60,000', 'bd': '2', 'ba': '2', 'sqft': '672', 'Type:': 'Mobile / Manufactured', 'Year built:': '1970', 'Heating:': 'Electric', 'Cooling:': 'Other', 'Parking:': '0 spaces', 'HOA:': '$170/mo', 'Price/sqft:': '$89'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 18, 320382), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/3087-Indian-River-Dr-NE-Palm-Bay-FL-32905/43496221_zpid/', 'price:': '$63,900', 'bd': '2', 'ba': '1', 'sqft': '470', 'Type:': 'Mobile / Manufactured', 'Year built:': '1965', 'Heating:': 'Electric', 'Cooling:': 'Other', 'Parking:': 'Garage, Garage - Attached', 'HOA:': '$175/mo', 'Price/sqft:': '$136'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 19, 209463), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/3172-Tangelo-Dr-132-Palm-Bay-FL-32905/2078751214_zpid/', 'price:': '$68,000', 'bd': '2', 'ba': '1', 'sqft': '672', 'Type:': 'Mobile / Manufactured', 'Year built:': '2005', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': '0 spaces', 'HOA:': '$170/mo', 'Price/sqft:': '$101'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 20, 143306), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/2998-Indian-River-Dr-NE-230-Palm-Bay-FL-32905/2083673924_zpid/', 'price:': '$68,000', 'bd': '2', 'ba': '2', 'sqft': '624', 'Type:': 'Mobile / Manufactured', 'Year built:': '1978', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': 'Carport, Covered', 'HOA:': '$170/mo', 'Price/sqft:': '$109'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 21, 69155), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/1936-Live-Oak-St-NE-Palm-Bay-FL-32905/43492884_zpid/', 'price:': '$69,900', 'bd': '2', 'ba': '2', 'sqft': '864', 'Type:': 'Single Family', 'Year built:': '1982', 'Heating:': 'No Data', 'Cooling:': 'No Data', 'Parking:': 'Off-street', 'Lot:': '4,791 sqft', 'Price/sqft:': '$81'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 21, 906707), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/2536-Chatham-Way-NE-Palm-Bay-FL-32905/43493090_zpid/', 'price:': '$75,000', 'bd': '2', 'ba': '1', 'sqft': '766', 'Type:': 'Mobile / Manufactured', 'Year built:': '1975', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': 'Carport, Covered', 'Price/sqft:': '$98'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 22, 858391), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/999-Mandarin-Dr-NE-Palm-Bay-FL-32905/104075178_zpid/', 'price:': '$79,500', 'Square': '10,454', 'Type:': 'Vacant Land', 'Year built:': 'No Data', 'Heating:': 'No Data', 'Cooling:': 'No Data', 'Parking:': '0 spaces', 'HOA:': '$3/mo'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 23, 739924), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/3525-Pinewood-Dr-NE-13-Palm-Bay-FL-32905/84638499_zpid/', 'price:': '$79,900', 'bd': '2', 'ba': '2', 'sqft': '1,036', 'Type:': 'Condo', 'Year built:': '1985', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': '0 spaces', 'HOA:': '$226/mo', 'Price/sqft:': '$77'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 24, 693095), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/2516-Haverhill-Rd-NE-Palm-Bay-FL-32905/43493067_zpid/', 'price:': '$81,000', 'bd': '2', 'ba': '2', 'sqft': '673', 'Type:': 'Mobile / Manufactured', 'Year built:': '1974', 'Heating:': 'No Data', 'Cooling:': 'No Data', 'Parking:': 'Carport', 'Price/sqft:': '$120'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 25, 546644), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/2547-Chatham-Way-NE-Palm-Bay-FL-32905/43492314_zpid/', 'price:': '$84,900', 'bd': '2', 'ba': '2', 'sqft': '845', 'Type:': 'Mobile / Manufactured', 'Year built:': '1986', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': 'Carport, Garage', 'Price/sqft:': '$100'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 26, 513552), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/3512-Tree-Ridge-Ln-90206-Palm-Bay-FL-32905/2077696909_zpid/', 'price:': '$84,900', 'bd': '2', 'ba': '2', 'sqft': '1,170', 'Type:': 'Townhouse', 'Year built:': '1980', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': '0 spaces', 'HOA:': '$83/mo', 'Lot:': '871 sqft', 'Price/sqft:': '$73'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 27, 472948), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/941-Mandarin-Dr-NE-Palm-Bay-FL-32905/104118004_zpid/', 'price:': '$85,000', 'Acres': '0.58', 'Type:': 'Vacant Land', 'Year built:': 'No Data', 'Heating:': 'No Data', 'Cooling:': 'No Data', 'Parking:': '0 spaces'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 28, 351998), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/2399-Ersoff-Blvd-NE-Palm-Bay-FL-32905/43492893_zpid/', 'price:': '$85,000', 'bd': '3', 'ba': '2', 'sqft': '1,288', 'Type:': 'Mobile / Manufactured', 'Year built:': '1978', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': 'Carport, Covered', 'HOA:': '$35/mo', 'Price/sqft:': '$66'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 29, 222741), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/1955-Live-Oak-St-NE-Palm-Bay-FL-32905/43492901_zpid/', 'price:': '$85,900', 'bd': '2', 'ba': '2', 'sqft': '1,039', 'Type:': 'Mobile / Manufactured', 'Year built:': '1984', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': 'Carport, Covered', 'HOA:': '$35/mo', 'Price/sqft:': '$83'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 30, 116746), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/2130-Forest-Knoll-Dr-NE-APT-102-Palm-Bay-FL-32905/2083755100_zpid/', 'price:': '$88,900', 'bd': '2', 'ba': '2', 'sqft': '1,069', 'Type:': 'Condo', 'Year built:': '1983', 'Heating:': 'Electric', 'Cooling:': 'None', 'Parking:': 'None', 'HOA:': '$250/mo', 'Price/sqft:': '$83'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 30, 999379), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/2100-Forest-Knoll-Dr-NE-APT-204-Palm-Bay-FL-32905/71031679_zpid/', 'price:': '$92,000', 'bd': '2', 'ba': '2', 'sqft': '1,069', 'Type:': 'Condo', 'Year built:': '1983', 'Heating:': 'Forced air, Electric', 'Cooling:': 'Central', 'Parking:': 'None', 'HOA:': '$250/mo', 'Price/sqft:': '$86'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 31, 952191), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/2190-Forest-Knoll-Dr-NE-90213-Palm-Bay-FL-32905/2077283059_zpid/', 'price:': '$95,000', 'bd': '2', 'ba': '2', 'sqft': '--', 'Type:': 'Condo', 'Year built:': '1983', 'Heating:': 'No Data', 'Cooling:': 'No Data', 'Parking:': '0 spaces'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 33, 270673), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/2190-Forest-Knoll-Dr-90213-Palm-Bay-FL-32905/2077283836_zpid/', 'price:': '$95,000', 'bd': '2', 'ba': '2', 'sqft': '1,069', 'Type:': 'Condo', 'Year built:': '1983', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': '0 spaces', 'HOA:': '$250/mo', 'Price/sqft:': '$89'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 34, 204993), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/1143-Wild-Rose-Dr-NE-Palm-Bay-FL-32905/43496554_zpid/', 'price:': '$98,650', 'bd': '3', 'ba': '1', 'sqft': '901', 'Type:': 'Single Family', 'Year built:': '1959', 'Heating:': 'Other, Electric', 'Cooling:': 'Central', 'Parking:': 'Carport, Covered', 'Lot:': '7,405 sqft'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 35, 136321), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/4121-Pinewood-Dr-NE-6-Palm-Bay-FL-32905/84635430_zpid/', 'price:': '$95,000', 'bd': '2', 'ba': '2', 'sqft': '1,036', 'Type:': 'Condo', 'Year built:': '1985', 'Heating:': 'No Data', 'Cooling:': 'No Data', 'Parking:': '0 spaces', 'HOA:': '$226/mo', 'Price/sqft:': '$92'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 36, 39772), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/1757-Coco-Plum-St-NE-Palm-Bay-FL-32905/43492734_zpid/', 'price:': '$95,982', 'bd': '2', 'ba': '2', 'sqft': '1,118', 'Type:': 'Mobile / Manufactured', 'Year built:': '1979', 'Heating:': 'No Data', 'Cooling:': 'No Data', 'Parking:': 'Carport', 'HOA:': '$35/mo'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 36, 890740), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/1698-Sunny-Brook-Ln-NE-APT-G211-Palm-Bay-FL-32905/54618601_zpid/', 'price:': '$98,000', 'bd': '2', 'ba': '2', 'sqft': '862', 'Type:': 'Condo', 'Year built:': '1984', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': '0 spaces', 'HOA:': '$285/mo', 'Price/sqft:': '$114'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 37, 803093), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/1657-Sunny-Brook-Ln-NE-APT-A104-Palm-Bay-FL-32905/54618682_zpid/', 'price:': '$98,000', 'bd': '2', 'ba': '2', 'sqft': '862', 'Type:': 'Condo', 'Year built:': '1984', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': '0 spaces', 'HOA:': '$285/mo', 'Price/sqft:': '$114'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 38, 692542), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/3512-Overlook-Dr-NE-54-Palm-Bay-FL-32905/43508624_zpid/', 'price:': '$98,500', 'bd': '1', 'ba': '1', 'sqft': '672', 'Type:': 'Townhouse', 'Year built:': '1986', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': 'Garage - Attached, Covered', 'HOA:': '$100/mo', 'Lot:': '4,356 sqft', 'Price/sqft:': '$147'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 39, 553992), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/2130-Forest-Knoll-Dr-NE-APT-110-Palm-Bay-FL-32905/2083578387_zpid/', 'price:': '$98,900', 'bd': '2', 'ba': '2', 'sqft': '1,069', 'Type:': 'Condo', 'Year built:': '1995', 'Heating:': 'Forced air, Electric', 'Cooling:': 'Central', 'Parking:': 'Off-street, Covered', 'HOA:': '$250/mo', 'Price/sqft:': '$93'}
# {'date': datetime.datetime(2020, 12, 26, 3, 19, 40, 429808), 'zipcode:': '32905', 'city:': 'Palm Bay', 'county': 'Brevard', 'url': 'https://www.zillow.com/homedetails/1301-Arlington-Ln-NE-APT-106-Palm-Bay-FL-32905/66683849_zpid/', 'price:': '$99,000', 'bd': '2', 'ba': '3', 'sqft': '1,140', 'Type:': 'Townhouse', 'Year built:': '1986', 'Heating:': 'Electric', 'Cooling:': 'Central', 'Parking:': '0 spaces', 'HOA:': '$250/mo', 'Lot:': '435 sqft', 'Price/sqft:': '$87'}
# 200
